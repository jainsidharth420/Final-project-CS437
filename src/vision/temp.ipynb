# %%
from inference_sdk import InferenceHTTPClient, InferenceConfiguration

CLIENT = InferenceHTTPClient(
    api_url="https://outline.roboflow.com",
    api_key="lwcDLr14Lt1dIiH65dvJ"
)

result = CLIENT.infer('IMG_1207.JPG', model_id="chessboard-segmentation/1")
result
# Out:
# {'time': 0.12008691699998053,
#  'image': {'width': 4284, 'height': 5712},
#  'predictions': [{'x': 2161.5234375,
#    'y': 3254.8359375,
#    'width': 3497.484375,
#    'height': 2036.015625,
#    'confidence': 0.9504984021186829,
#    'class': '0',
#    'points': [{'x': 1017.45, 'y': 2240.175},
#     {'x': 1010.7562499999999, 'y': 2249.1000000000004},
#     {'x': 1010.7562499999999, 'y': 2258.025},
#     {'x': 1004.0625, 'y': 2266.9500000000003},
#     {'x': 1004.0625, 'y': 2275.875},
#     {'x': 997.3687499999999, 'y': 2284.8},
#     {'x': 997.3687499999999, 'y': 2302.65},
#     {'x': 990.675, 'y': 2311.5750000000003},
#     {'x': 990.675, 'y': 2347.275},
#     {'x': 983.98125, 'y': 2356.2000000000003},
#     {'x': 983.98125, 'y': 2382.9750000000004},
#     {'x': 977.2874999999999, 'y': 2391.9},
#     {'x': 977.2874999999999, 'y': 2400.8250000000003},
#     {'x': 970.59375, 'y': 2409.75},
#     {'x': 970.59375, 'y': 2427.6000000000004},
# ...

# %%
custom_configuration = InferenceConfiguration(confidence_threshold=0.15)


CLIENT = InferenceHTTPClient(
    api_url="https://detect.roboflow.com",
    api_key="lwcDLr14Lt1dIiH65dvJ"
)

with CLIENT.use_configuration(custom_configuration):
    result = CLIENT.infer("IMG_1207.JPG", model_id="chess_pieces-detection/1")
    print(result["predictions"])
# Out:
# [{'x': 1941.1875, 'y': 3868.4296875, 'width': 334.6875, 'height': 786.515625, 'confidence': 0.8592814803123474, 'class': 'white-bishop', 'class_id': 7, 'detection_id': '8f9880d7-3e10-429c-a08e-25ee8d5cc703'}, {'x': 1743.1640625, 'y': 2220.09375, 'width': 184.078125, 'height': 379.3125, 'confidence': 0.852518618106842, 'class': 'black-pawn', 'class_id': 4, 'detection_id': '0757ab0c-5278-47de-834c-09184b7ca8be'}, {'x': 2535.2578125, 'y': 2234.0390625, 'width': 184.078125, 'height': 418.359375, 'confidence': 0.850641667842865, 'class': 'black-pawn', 'class_id': 4, 'detection_id': 'ae912256-2c25-41b9-a25d-ac92c4f18b94'}, {'x': 655.4296875, 'y': 3977.203125, 'width': 362.578125, 'height': 535.5, 'confidence': 0.799791693687439, 'class': 'white-rook', 'class_id': 12, 'detection_id': '4ff4fcea-fadb-4947-9afb-10b86272ef04'}, {'x': 1946.765625, 'y': 3570.0, 'width': 245.4375, 'height': 423.9375, 'confidence': 0.7901315093040466, 'class': 'white-pawn', 'class_id': 10, 'detection_id': '441d1aba
# ...

# %%
from roboflow import Roboflow
import supervision as sv
import cv2

rf = Roboflow(api_key="lwcDLr14Lt1dIiH65dvJ")
project = rf.workspace().project("chessboard-segmentation")
model = project.version(1).model

result = model.predict("").json()

labels = [item["class"] for item in result["predictions"]]

detections = sv.Detections.from_roboflow(result)

label_annotator = sv.LabelAnnotator()
mask_annotator = sv.MaskAnnotator()

image = cv2.imread("/Users/devgoyal/Desktop/datasets/train/images/IMG_1211.JPG")

annotated_image = mask_annotator.annotate(
    scene=image, detections=detections)
annotated_image = label_annotator.annotate(
    scene=annotated_image, detections=detections, labels=labels)

sv.plot_image(image=annotated_image, size=(16, 16))
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[2], line 9
#       6 project = rf.workspace().project("chessboard-segmentation")
#       7 model = project.version(1).model
# ----> 9 result = model.predict("/Users/devgoyal/Desktop/datasets/train/images/IMG_1211.JPG").json()
#      11 labels = [item["class"] for item in result["predictions"]]
#      13 detections = sv.Detections.from_roboflow(result)
#
# File ~/anaconda3/lib/python3.11/site-packages/roboflow/models/instance_segmentation.py:59, in InstanceSegmentationModel.predict(self, image_path, confidence)
#      37 def predict(self, image_path, confidence=40):
#      38     """
#      39     Infers detections based on image from a specified model and image path.
#      40
#    (...)
#      57         >>> prediction = model.predict("YOUR_IMAGE.jpg")
# ...

# %%
from roboflow import Roboflow
import supervision as sv
import cv2

rf = Roboflow(api_key="lwcDLr14Lt1dIiH65dvJ")
project = rf.workspace().project("chessboard-without-annoying-edges")
model = project.version(1).model

result = model.predict("/Users/devgoyal/Desktop/datasets/train/images/IMG_1211.JPG").json()

labels = [item["class"] for item in result["predictions"]]

detections = sv.Detections.from_roboflow(result)

label_annotator = sv.LabelAnnotator()
mask_annotator = sv.MaskAnnotator()

image = cv2.imread("your_image.jpg")

annotated_image = mask_annotator.annotate(
    scene=image, detections=detections)
annotated_image = label_annotator.annotate(
    scene=annotated_image, detections=detections, labels=labels)

sv.plot_image(image=annotated_image, size=(16, 16))
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[4], line 9
#       6 project = rf.workspace().project("chessboard-without-annoying-edges")
#       7 model = project.version(1).model
# ----> 9 result = model.predict("/Users/devgoyal/Desktop/datasets/train/images/IMG_1211.JPG").json()
#      11 labels = [item["class"] for item in result["predictions"]]
#      13 detections = sv.Detections.from_roboflow(result)
#
# File ~/anaconda3/lib/python3.11/site-packages/roboflow/models/instance_segmentation.py:59, in InstanceSegmentationModel.predict(self, image_path, confidence)
#      37 def predict(self, image_path, confidence=40):
#      38     """
#      39     Infers detections based on image from a specified model and image path.
#      40
#    (...)
# ...
